# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# !ls
# Out:
# EMGaussian.data  Exercises_05nov2014.pdf
# EMGaussian.test  MVA_DM2_mohamed_naitnbark.ipynb

# %%
# !head EMGaussian.data
# Out:
# 0.91029 0.016192
# -2.531 6.6981
# 4.3602 8.3541
# -0.70489 -0.51343
# -5.7383 -6.2088
# -4.4819 -4.7127
# 0.90842 0.38202
# 4.4273 5.8406
# -5.5724 3.9576
# 4.256 -0.71465

# %%
data = loadtxt("EMGaussian.data", delimiter=" ")

# %%
plot(data[:,0],data[:,1],"ro")
